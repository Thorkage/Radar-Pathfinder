# %% [markdown]
# # Evaluating/ validating Pathfinder + UWiBaSS snow depths against MP

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore")

import sys
import os
sys.path.append(os.path.abspath('../Pathfinder'))

from helper_functions import *
from radar_functions import *
from pathfinder import *
from attach_grounddata import *
from add_dataflashlog import *
from clicki_tool import *

# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
campaigns = [
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_SIOS',
    '2022_CIRFA',
    '2024_SIOS',
    '2024_ESASnowDrone',
    '2024_ESASnowDrone',
    '2025_St3TARTFO',
    ]

targets = [
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'land',
    'sea ice',
    'land',
    'sea ice',
    'sea ice',
    'sea ice'
]

sets = [
    '29_03_2022_4',
    '29_03_2022_9',
    '30_03_2022_1',
    '30_03_2022_2',
    '30_03_2022_3',
    '30_03_2022_4',
    '30_03_2022_6',
    '30_03_2022_9',
    '31_03_2022_2',
    '31_03_2022_10',
    '31_03_2022_11',
    '01_04_2022_1',
    '01_04_2022_2',
    '01_04_2022_5',
    '28_04_2022_1',
    '26_04_2024_3',
    '30_04_2024_1', 
    '01_05_2024_2',
    '24_04_2025_3'
    ]   #,'01_04_2022_10', 31_03_2022_3



colors_list = ['#2f4f4f',
               '#a52a2a',
               '#006400',
               '#000080',
               '#ff8c00',
               '#ffff00',
               '#00ff00',
               '#00bfff',
               '#0000ff',
               '#ff00ff',
               '#dda0dd',
               '#ff1493',
               '#98fb98',
               '#ffdead',
               "#78a7b1",
               'grey',
               "#3f062e",
               "#5f3900",
               "#9541bf"
               ]  #, '#dcdcdc']

# %%
for k, (target, datasetID, campaignID) in enumerate(zip(targets, sets, campaigns)):

    
    RADAR = load_RADAR(radar_type='UWiBaSS',
                    datasetID=datasetID,
                    campaignID=campaignID,
                    yaml_file="./campaigns.yaml",
                    # from_scratch=True
                    )
    
    # Setting the Pathfinder parameters
    PF_parameters = {
        'a': 1,         #weight of radar image in cost function, standard: 1
        'b': 1,         #weight of (hessian) ridges in cost function, standard: 1
        'c': 2,         #weight of peak prominance in cost function, standard: 2
        'd': 2,         #weight of the localized cross-correlation, standard: 2
        'db': 0,        #depth bias term (used to have a bias towards top for top layer, bottom for bottom layer), standard: 0
        'sigma': 1,     #for blurring the cost map, 1 = no blurring, standard: 1
        'jumpiness': 2  #vertical freedom for the pathfinder (larger jumps are penalized), standard: 2
        }

    # Does RADAR have flightstate data?
    has_flightstate = True

    # Does RADAR have geolocation data?
    has_geolocation = True

    # Is there in-situ data (probe/ snow profile) that you want to add? Could be for validation or to view in the clicki_tool later
    add_insitu_data = True
    #TODO even if add_insitu_data = False, we need to add the eps_r + uncertainty! Best derived by providing a density?

    # This is a UWiBaSS specific flag. Auxilliary data is added from the ardupilot dataflashlogs and some processing is done there
    check_dataflashlog = True 

    #TODO: Even if add_insitu_data = False, we return the 4 vars, this is of course not nice and pretty much unintuitive
    RADAR, df_MP, df_SP, dict_SP = populate_datafields(RADAR,
                                        PF_parameters=PF_parameters,
                                        has_flightstate=has_flightstate,
                                        has_geolocation=has_geolocation,
                                        add_insitu_data=add_insitu_data,
                                        check_dataflashlog=check_dataflashlog,
                                        force_RPCA=False
                                        )
    RADAR.PF_radar_uncertainty, RADAR.PF_sampling_uncertainty, RADAR.PF_top_interface_SNR, RADAR.PF_bottom_interface_SNR, RADAR.range_resolution_air, RADAR.range_resolution_snow = calculate_radar_uncertainties(RADAR, RADAR.rx_rpca[:,:], RADAR.PF_cost_maps['unbiased'])
    RADAR.PF_snow_uncertainty = calculate_snow_depth_uncertainty(RADAR)
    RADAR.PF_total_uncertainty = calculate_total_uncertainty(RADAR)
    with open(RADAR.full_path, 'wb') as outp:
        pickle.dump(RADAR, outp, pickle.HIGHEST_PROTOCOL)
    
# make_nc_file(RADAR)
# Out:
# Dataset 29_03_2022_4 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/29_03_2022_4/uwibass_object.pkl
# dict_keys(['rxc', 'radar_type', 'bandwidth', 'datasetID', 'campaignID', 'data_path', 'config_paths', 'full_path', 'rx1', 'rx2', 'rx_raw', 'fasttime', 'dft', 'range_air', 'slowtime', 'timestamp', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'rx_rpca', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'UTM_x', 'UTM_y', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'compensated_pitch', 'CTUN_SAlt_filtered', 'target_type', 'altitude_mask', 'PF_parameters', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_snow_depth', 'MP_N_points', 'MP_indices', 'MP_snow_depth_in_range_bins', 'PF_cost_maps', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'range_snow', 'PF_snow_depth_air', 'PF_snow_depth', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_snow_uncertainty', 'PF_total_uncertainty'])
# Co-locating in-situ data to radar footprints..
# Dataset 29_03_2022_9 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/29_03_2022_9/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'UTM_x', 'UTM_y', 'range_snow', 'MP_snow_depth', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'closest_snowprofile', 'PF_snow_profile_eps_r', 'PF_top_interface', 'PF_bottom_interface', 'PF_snow_depth_T', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# No snow profiles found within the specified radius, falling back to replacement eps_r value: 1.5
# Dataset 30_03_2022_1 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_1/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'gps_alt', 'rxraw', 'UTM_x', 'UTM_y', 'range_snow', 'MP_snow_depth', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'rx_rpca_T', 'top_interface_PF', 'bottom_interface_PF', 'dataset_name', 'datetime_timestamp', 'PF_snow_profile_eps_r', 'PF_top_interface', 'PF_bottom_interface', 'PF_snow_depth_T', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'closest_snowprofile', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 30_03_2022_2 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_2/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'UTM_x', 'UTM_y', 'range_snow', 'MP_snow_depth', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'PF_snow_profile_eps_r', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'cost_maps', 'PF_snow_depth_T', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 30_03_2022_3 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_3/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'UTM_x', 'UTM_y', 'MP_snow_depth', 'snow_profile_eps_r', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'PF_snow_profile_eps_r', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'PF_cost_maps', 'range_snow', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 30_03_2022_4 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_4/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'MP_snow_depth', 'distance_to_MP', 'n_MP_neighbors', 'closest_snowprofile', 'PF_snow_profile_eps_r', 'MP_snow_depth_in_indices', 'rx_rpca_T', 'PF_top_interface', 'PF_bottom_interface', 'range_snow', 'PF_snow_depth_T', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'UTM_x', 'UTM_y', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 30_03_2022_6 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_6/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'UTM_x', 'UTM_y', 'range_snow', 'MP_snow_depth', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'PF_snow_profile_eps_r', 'PF_top_interface', 'PF_bottom_interface', 'PF_snow_depth_T', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 30_03_2022_9 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_9/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'UTM_x', 'UTM_y', 'range_snow', 'MP_snow_depth', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'PF_snow_profile_eps_r', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 31_03_2022_2 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/31_03_2022_2/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'MP_snow_depth', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'closest_snowprofile', 'PF_snow_profile_eps_r', 'MP_snow_depth_in_indices', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'rpca_lambda', 'rx_rpca', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'PF_cost_maps', 'range_snow', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'UTM_x', 'UTM_y', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# No snow profiles found within the specified radius, falling back to replacement eps_r value: 1.5
# Dataset 31_03_2022_10 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/31_03_2022_10/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'depth_air', 'depth_snow', 'depth_vac', 'rx_rpca_T', 'UTM_x', 'UTM_y', 'range_snow', 'MP_snow_depth', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'dataset_name', 'datetime_timestamp', 'PF_snow_profile_eps_r', 'PF_top_interface', 'PF_bottom_interface', 'PF_snow_depth_T', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'cost_maps', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'range_resolution_air', 'range_resolution_snow', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 31_03_2022_11 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/31_03_2022_11/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'rxh', 'rxbp', 'rxw', 'eps_r', 'UTMx', 'UTMy', 'UTM_x', 'UTM_y', 'range_snow', 'MP_snow_depth', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'closest_snowprofile', 'PF_snow_profile_eps_r', 'PF_top_interface', 'PF_bottom_interface', 'PF_snow_depth_T', 'data_path', 'PF_parameters', 'utm_zone', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'cost_maps', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_internal_layers', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'compensated_pitch', 'CTUN_SAlt_filtered', 'PF_snow_profile_eps_r_uncertainty', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'rx_rpca', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 01_04_2022_1 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_04_2022_1/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'MP_snow_depth', 'distance_to_MP', 'n_MP_neighbors', 'closest_snowprofile', 'PF_snow_profile_eps_r', 'MP_snow_depth_in_indices', 'rx_rpca_T', 'PF_top_interface', 'PF_bottom_interface', 'range_snow', 'PF_snow_depth_T', 'rpca_lambda', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'UTM_x', 'UTM_y', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 01_04_2022_2 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_04_2022_2/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'MP_snow_depth', 'distance_to_MP', 'n_MP_neighbors', 'closest_snowprofile', 'PF_snow_profile_eps_r', 'MP_snow_depth_in_indices', 'PF_top_interface', 'PF_bottom_interface', 'range_snow', 'PF_snow_depth_T', 'rpca_lambda', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'UTM_x', 'UTM_y', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 01_04_2022_5 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_04_2022_5/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'depth_air', 'depth_snow', 'depth_vac', 'eps_r', 'UTMx', 'UTMy', 'rxraw', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'MP_snow_depth', 'distance_to_MP', 'n_MP_neighbors', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'PF_snow_profile_eps_r', 'MP_snow_depth_in_indices', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'cost_maps', 'range_snow', 'PF_snow_depth_T', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'rx_rpca', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'PF_snow_depth_air', 'PF_snow_depth_uncertainty', 'PF_snow_uncertainty', 'PF_total_uncertainty', 'UTM_x', 'UTM_y', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 28_04_2022_1 from campaign 2022_CIRFA is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/28_04_2022_1/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rx1h', 'rx2h', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'rxh', 'rxbp', 'rxw', 'eps_r', 'depth_air', 'depth_snow', 'depth_vac', 'UTMx', 'UTMy', 'rxraw', 'rx_rpca_T', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'compensated_pitch', 'data_path', 'PF_parameters', 'utm_zone', 'MP_snow_depth', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'PF_snow_profile_eps_r', 'PF_snow_profile_eps_r_uncertainty', 'MP_snow_depth_in_indices', 'is_sea_ice', 'CTUN_SAlt_filtered', 'expected_snow_depth', 'altitude_mask', 'rx_rpca', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'PF_cost_maps', 'range_snow', 'PF_snow_depth_air', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_snow_depth_uncertainty', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'UTM_x', 'UTM_y', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 26_04_2024_3 from campaign 2024_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/26_04_2024_3/uwibass_object.pkl
# dict_keys(['rxc', 'radar_type', 'bandwidth', 'datasetID', 'campaignID', 'data_path', 'config_paths', 'full_path', 'rx1', 'rx2', 'rx_raw', 'fasttime', 'dft', 'range_air', 'slowtime', 'timestamp', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'rx_rpca', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'UTM_x', 'UTM_y', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'compensated_pitch', 'CTUN_SAlt_filtered', 'target_type', 'altitude_mask', 'PF_parameters', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_snow_depth', 'MP_N_points', 'MP_snow_depth_in_range_bins', 'PF_cost_maps', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'range_snow', 'PF_snow_depth_air', 'PF_snow_depth', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_snow_uncertainty', 'PF_total_uncertainty', 'MP_indices'])
# Co-locating in-situ data to radar footprints..
# Dataset 30_04_2024_1 from campaign 2024_ESASnowDrone is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_04_2024_1/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'dataset_name', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'compensated_pitch', 'data_path', 'PF_parameters', 'utm_zone', 'MP_snow_depth', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'PF_snow_profile_eps_r', 'PF_snow_profile_eps_r_uncertainty', 'MP_snow_depth_in_indices', 'is_sea_ice', 'CTUN_SAlt_filtered', 'expected_snow_depth', 'altitude_mask', 'rpca_lambda', 'rx_rpca', 'PF_top_interface', 'PF_bottom_interface', 'PF_internal_layers', 'PF_cost_maps', 'range_snow', 'PF_snow_depth_air', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_snow_depth_uncertainty', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'UTM_x', 'UTM_y', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 01_05_2024_2 from campaign 2024_ESASnowDrone is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_05_2024_2/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'roll', 'pitch', 'lat', 'lon', 'alt', 'rngf', 'dist', 'gps_alt', 'top', 'bottom', 'bottom_no_rec', 'depth_air', 'depth_snow', 'depth_vac', 'rxraw', 'rx_rpca_T', 'dataset_name', 'top_interface_PF', 'bottom_interface_PF', 'eps_r_T', 'range_snow', 'snow_depth_T', 'UTM_x', 'UTM_y', 'MP_snow_depth', 'snow_profile_eps_r', 'MP_snow_depth_in_indices', 'distance_to_MP', 'n_MP_neighbors', 'PF_top_interface', 'PF_bottom_interface', 'PF_snow_depth_T', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'data_path', 'PF_parameters', 'utm_zone', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'closest_snowprofile', 'SP_indices', 'SP_log_UTM_x', 'SP_log_UTM_y', 'SP_top_layers', 'SP_bottom_layers', 'PF_snow_profile_eps_r', 'is_sea_ice', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'compensated_pitch', 'PF_snow_profile_eps_r_uncertainty', 'CTUN_SAlt_filtered', 'rx_rpca', 'PF_snow_depth_air', 'range_resolution_air', 'range_resolution_snow', 'PF_snow_depth_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_closest_name', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..
# Dataset 24_04_2025_3 from campaign 2025_St3TARTFO is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/24_04_2025_3/uwibass_object.pkl
# dict_keys(['rxc', 'rx', 'rx1', 'rx2', 'rxh', 'rxbp', 'rxw', 'rxsvd', 'rxraw', 'fasttime', 'slowtime', 'timestamp', 'range_air', 'yaw', 'pitch', 'roll', 'lat', 'lon', 'alt', 'rngf', 'gps_alt', 'dist', 'rx_rpca', 'rx_w_rpca', 'UTM_x', 'UTM_y', 'top_interface_PF', 'bottom_interface_PF', 'dataset_name', 'eps_r', 'range_snow', 'snow_depth_T', 'eps_r_T', 'snow_profile_eps_r', 'PF_top_interface', 'PF_bottom_interface', 'PF_snow_depth_T', 'datetime_timestamp', 'dataflashlog_path', 'GPS_Lat', 'GPS_Lng', 'GPS_Status', 'GPS_Alt', 'CTUN_Alt', 'CTUN_SAlt', 'POS_Alt', 'BARO_Alt', 'log_UTM_x', 'log_UTM_y', 'compensated_pitch', 'data_path', 'PF_parameters', 'utm_zone', 'MP_snow_depth', 'MP_N_neighbors', 'MP_indices', 'MP_distances', 'PF_snow_profile_eps_r', 'PF_snow_profile_eps_r_uncertainty', 'MP_snow_depth_in_indices', 'is_sea_ice', 'CTUN_SAlt_filtered', 'expected_snow_depth', 'altitude_mask', 'PF_internal_layers', 'PF_cost_maps', 'PF_snow_depth_air', 'PF_snow_depth', 'PF_top_interface_elev', 'PF_bottom_interface_elev', 'bandwidth', 'dft', 'PF_radar_uncertainty', 'PF_sampling_uncertainty', 'PF_top_interface_SNR', 'PF_bottom_interface_SNR', 'range_resolution_air', 'range_resolution_snow', 'PF_snow_depth_uncertainty', 'PF_top_interface_roughness', 'PF_bottom_interface_roughness', 'PF_snow_uncertainty', 'PF_total_uncertainty', 'radar_type', 'datasetID', 'campaignID', 'config_paths', 'full_path', 'has_flightstate', 'has_geolocation', 'add_insitu_data', 'check_dataflashlog', 'rx_rpca_lambda', 'ATT_Pitch', 'ATT_Roll', 'ATT_Yaw', 'target_type', 'UTM_zone', 'footprints', 'SP_bulk_eps_r', 'SP_bulk_eps_r_uncertainty', 'MP_N_points', 'MP_snow_depth_in_range_bins'])
# Co-locating in-situ data to radar footprints..

# %%
R2s = []
RMSEs = []
MAEs = []

counterrrrrr = 0

xvar = []
yvar = []
yerr = []
maskis = []
sea_ice_maskis = []
colorsi = []
colorsi2 = []
markersi = []
count_under_penetration_all = 0
count_under_penetration_true = 0

for k, (target, datasetID, campaignID) in enumerate(zip(targets, sets, campaigns)):

    
    RADAR = load_RADAR(radar_type='UWiBaSS',
                    datasetID=datasetID,
                    campaignID=campaignID,
                    yaml_file="./campaigns.yaml"
                    )
    counterrrrrr += len(np.unique(RADAR.MP_snow_depth[~np.isnan(RADAR.MP_snow_depth)]))
    
    
    unique_MP_indices = np.unique([item for sublist in np.array(RADAR.MP_indices, dtype=object)[RADAR.altitude_mask] for item in sublist])
    internals = RADAR.PF_internal_layers['paths']

    MP_depths = []
    UWB_depths = []
    UWB_uncertainties = []
    colors = []
    marker = []
    colors2 = []
    maski = []
    sea_ice_maski = []
    j = 0
    
    for ind in unique_MP_indices:
        colors.append('grey')
        marker.append('o' if target=='land' else '^')
        colors2.append(colors_list[k])
        maski.append(True)
        sea_ice_maski.append(True if target=='sea ice' else False)
        indices = [i for i, item in enumerate(RADAR.MP_indices) if ind in item]
        
        ind_UWB_depths = np.array([RADAR.PF_snow_depth[i] for i, item in enumerate(RADAR.MP_indices) if ind in item])
        ind_UWB_uncs = np.array([RADAR.PF_total_uncertainty[i] for i, item in enumerate(RADAR.MP_indices) if ind in item])
                    
        ind_MP_depth = np.nanmedian([RADAR.MP_snow_depth[i] for i, item in enumerate(RADAR.MP_indices) if ind in item])
        ind_MP_index = np.nanmedian([RADAR.MP_snow_depth_in_range_bins[i] for i, item in enumerate(RADAR.MP_indices) if ind in item])

        if np.all(ind_MP_depth/100 < ind_UWB_depths - RADAR.range_resolution_snow/4):
            count_under_penetration_all += 1
            
            for path in internals:
                py, px = list(zip(*path))
                py = np.array(py)
                py_extended = np.unique(np.concatenate([py, py-2, py - 1, py + 1, py + 2]))
                px = np.array(px)
                
                if any(i in px for i in indices):
                    
                    if ind_MP_index in py_extended:
                        colors[j] = 'firebrick'
                        count_under_penetration_true += 1
                        maski[j] = False

        
        UWB_depths.append(ind_UWB_depths[np.argmin(np.abs(ind_UWB_depths - ind_MP_depth/100))])
        MP_depths.append(ind_MP_depth/100)

        UWB_uncertainties.append(ind_UWB_uncs[np.argmin(np.abs(ind_UWB_depths - ind_MP_depth/100))])
        j += 1

    R2s.append(np.corrcoef(np.array(MP_depths)[maski], np.array(UWB_depths)[maski])[0, 1])
    RMSEs.append(np.sqrt(np.mean((np.array(MP_depths)[maski] - np.array(UWB_depths)[maski])**2)))
    MAEs.append(np.mean(np.abs(np.array(MP_depths)[maski] - np.array(UWB_depths)[maski])))

        

    xvar.append(np.array(MP_depths))
    yvar.append(np.array(UWB_depths))
    yerr.append(np.array(UWB_uncertainties))
    maskis.append(np.array(maski))
    colorsi.append(np.array(colors))
    markersi.append(np.array(marker))
    sea_ice_maskis.append(np.array(sea_ice_maski))
    colorsi2.append(np.array(colors2))
    # plot_MP_validation(uwibass, ax=ax, mode='snow_depth_best')
    
    del RADAR
    
xvars = np.concatenate(xvar)
yvars = np.concatenate(yvar)
yerrs = np.concatenate(yerr)
maskiss = np.concatenate(maskis)
colorsis = np.concatenate(colorsi)
colorsi2s = np.concatenate(colorsi2)
markersis = np.concatenate(markersi)
sea_ice_maskiss = np.concatenate(sea_ice_maskis)
RADAR = load_RADAR(radar_type='UWiBaSS',
                    datasetID=datasetID,
                    campaignID=campaignID,
                    yaml_file="./campaigns.yaml"
                    )
# Out:
# Dataset 29_03_2022_4 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/29_03_2022_4/uwibass_object.pkl
# Dataset 29_03_2022_9 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/29_03_2022_9/uwibass_object.pkl
# Dataset 30_03_2022_1 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_1/uwibass_object.pkl
# Dataset 30_03_2022_2 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_2/uwibass_object.pkl
# Dataset 30_03_2022_3 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_3/uwibass_object.pkl
# Dataset 30_03_2022_4 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_4/uwibass_object.pkl
# Dataset 30_03_2022_6 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_6/uwibass_object.pkl
# Dataset 30_03_2022_9 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_03_2022_9/uwibass_object.pkl
# Dataset 31_03_2022_2 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/31_03_2022_2/uwibass_object.pkl
# Dataset 31_03_2022_10 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/31_03_2022_10/uwibass_object.pkl
# Dataset 31_03_2022_11 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/31_03_2022_11/uwibass_object.pkl
# Dataset 01_04_2022_1 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_04_2022_1/uwibass_object.pkl
# Dataset 01_04_2022_2 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_04_2022_2/uwibass_object.pkl
# Dataset 01_04_2022_5 from campaign 2022_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_04_2022_5/uwibass_object.pkl
# Dataset 28_04_2022_1 from campaign 2022_CIRFA is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/28_04_2022_1/uwibass_object.pkl
# Dataset 26_04_2024_3 from campaign 2024_SIOS is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/26_04_2024_3/uwibass_object.pkl
# Dataset 30_04_2024_1 from campaign 2024_ESASnowDrone is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/30_04_2024_1/uwibass_object.pkl
# Dataset 01_05_2024_2 from campaign 2024_ESASnowDrone is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/01_05_2024_2/uwibass_object.pkl
# Dataset 24_04_2025_3 from campaign 2025_St3TARTFO is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/24_04_2025_3/uwibass_object.pkl
# Dataset 24_04_2025_3 from campaign 2025_St3TARTFO is loaded from /Volumes/PortableSSD/SnowDrone/UWiBaSS/24_04_2025_3/uwibass_object.pkl

# %%
fig = plt.figure(figsize=(10, 8), constrained_layout=True, dpi=600)

gs = gridspec.GridSpec(2, 6, height_ratios=[3, 1], figure=fig)

ax_top_left  = fig.add_subplot(gs[0, 0:3])   
ax_top_right = fig.add_subplot(gs[0, 3:6])  

ax_bottom_1 = fig.add_subplot(gs[1, 0:2])
ax_bottom_2 = fig.add_subplot(gs[1, 2:4])
ax_bottom_3 = fig.add_subplot(gs[1, 4:6])

ax_top_left.set_aspect('equal', adjustable='box')
ax_top_right.set_aspect('equal', adjustable='box')
import string
axes = [ax_top_left, ax_top_right, ax_bottom_1, ax_bottom_2, ax_bottom_3]
for idx, a in enumerate(axes):
    a.grid(ls=':', axis='y')
    a.spines['top'].set_color('white')
    a.spines['right'].set_color('white')

ax_top_left.text(0.03, 1, f'a)', transform=ax_top_left.transAxes,
        fontsize=16, fontweight='bold', va='top', ha='left')
ax_top_right.text(0.03, 1, f'b)', transform=ax_top_right.transAxes,
        fontsize=16, fontweight='bold', va='top', ha='left')
ax_bottom_1.text(0.03, 1.05, f'c)', transform=ax_bottom_1.transAxes,
        fontsize=16, fontweight='bold', va='top', ha='left')
ax_bottom_2.text(0.03, 1.05, f'd)', transform=ax_bottom_2.transAxes,
        fontsize=16, fontweight='bold', va='top', ha='left')
ax_bottom_3.text(0.03, 1.05, f'e)', transform=ax_bottom_3.transAxes,
        fontsize=16, fontweight='bold', va='top', ha='left')

ax_top_left.set_xlabel('Magnaprobe snow depth [m]')
ax_top_left.set_ylabel('UWiBaSS & Pathfinder snow depth [m]')

ax_top_right.set_xlabel('Magnaprobe snow depth [m]')
ax_top_right.set_ylabel('UWiBaSS & Pathfinder snow depth [m]')

ax_bottom_1.set_ylabel('R$^\\text{2}$')
ax_bottom_2.set_ylabel('RMSE [cm]')
ax_bottom_3.set_ylabel('MAE [cm]')

ax_bottom_1.set_yticks([0,0.25,0.5, 0.75])
ax_bottom_3.set_yticks([0, 5, 10])
ax_bottom_3.set_ylim(0, 13)
ax_bottom_1.set_xticklabels([])
ax_bottom_2.set_xticklabels([])
ax_bottom_3.set_xticklabels([])



mask = ~np.isnan(xvars) & ~np.isnan(yvars) & maskiss.astype(bool) & (yerrs < 0.1)
mask2 = ~np.isnan(xvars) & ~np.isnan(yvars)  & (yerrs < 0.1)

ax_top_right.errorbar(xvars[mask2], yvars[mask2], yerr=yerrs[mask2], color='silver', alpha=.5, fmt='none', ls='', lw=1)
ax_top_right.scatter(xvars[mask2], yvars[mask2], s=20, color=colorsis[mask2], alpha=.9, zorder=1000)


ax_top_left.errorbar(xvars[mask2], yvars[mask2], yerr=yerrs[mask2], color='silver', alpha=.5, fmt='none', ls='', lw=1)
scatter = mscatter(xvars[mask2], yvars[mask2], m=markersis[mask2], s=20, color=colorsi2s[mask2], alpha=.9, zorder=1000, ax=ax_top_left)
# scatter = mscatter(x, y, c=c, s=s, m=m, ax=ax)

ax_top_right.set_xlim(0, 1.7)
ax_top_right.set_ylim(0, 1.7)
ax_top_left.set_xlim(0, 1.7)
ax_top_left.set_ylim(0, 1.7)

# ODR FIT:
from scipy import odr
# --- define a linear function for ODR ---
def f_lin(B, x):
    return B[0] * x + B[1]  # B[0]=slope, B[1]=intercept

data = odr.RealData(xvars[mask], yvars[mask]) #, sy=yerr[mask]
model = odr.Model(f_lin)
odr_obj = odr.ODR(data, model, beta0=[1.0, 0.0])
out = odr_obj.run()

slope, intercept = out.beta

# compute fitted line & stats
xp = np.array([0, 1.7])
yp = intercept + slope * xp

ax_top_right.fill_between(xp, xp - RADAR.PF_sampling_uncertainty, xp + RADAR.PF_sampling_uncertainty, color='grey', label='Sampling precision', alpha=.2, zorder=0)
ax_top_right.plot(xp, xp, color='grey', linestyle='--', label='1:1 line')
ax_top_right.plot(xp, yp, color='deepskyblue', label='ODR', linewidth=4, zorder=1e6, alpha=.4)

ax_top_left.fill_between(xp, xp - RADAR.PF_sampling_uncertainty, xp + RADAR.PF_sampling_uncertainty, color='grey', label='Sampling precision', alpha=.2, zorder=0)
ax_top_left.plot(xp, xp, color='grey', linestyle='--', label='1:1 line')
ax_top_left.plot(xp, yp, color='deepskyblue', label='ODR', linewidth=4, zorder=1e6, alpha=.4)


# STATISTICS TEXT 

#ALL: 
# R² from ODR predictions
y_pred = intercept + slope * xvars[mask]
ss_res = np.sum((yvars[mask] - y_pred)**2)
ss_tot = np.sum((yvars[mask] - np.mean(yvars[mask]))**2)
r2_odr = 1 - ss_res / ss_tot

# RMSE between x and y (as you had it)
RMSE = np.sqrt(np.mean((xvars[mask] - yvars[mask])**2))
MAE = np.mean(np.abs(xvars[mask] - yvars[mask]))
bias = np.mean(yvars[mask] - xvars[mask])


#TERRESTRIAL: 
# R² from ODR predictions
mask_land = mask & (sea_ice_maskiss == False)
y_pred = intercept + slope * xvars[mask_land]
ss_res = np.sum((yvars[mask_land] - y_pred)**2)
ss_tot = np.sum((yvars[mask_land] - np.mean(yvars[mask_land]))**2)
r2_odr_terrestrial = 1 - ss_res / ss_tot

# RMSE between x and y (as you had it)
RMSE_terrestrial = np.sqrt(np.mean((xvars[mask_land] - yvars[mask_land])**2))
MAE_terrestrial = np.mean(np.abs(xvars[mask_land] - yvars[mask_land]))
bias_terrestrial = np.mean(yvars[mask_land] - xvars[mask_land])

#SEA ICE: 
# R² from ODR predictions
mask_seaice = mask & (sea_ice_maskiss == True)
y_pred = intercept + slope * xvars[mask_seaice]
ss_res = np.sum((yvars[mask_seaice] - y_pred)**2)
ss_tot = np.sum((yvars[mask_seaice] - np.mean(yvars[mask_seaice]))**2)
r2_odr_seaice = 1 - ss_res / ss_tot

# RMSE between x and y (as you had it)
RMSE_seaice = np.sqrt(np.mean((xvars[mask_seaice] - yvars[mask_seaice])**2))
MAE_seaice = np.mean(np.abs(xvars[mask_seaice] - yvars[mask_seaice]))
bias_seaice = np.mean(yvars[mask_seaice] - xvars[mask_seaice])


ax_top_left.text(
    0.97, 0.02,
    f"All:"
    f"\nR² = {r2_odr:.2f}"
    f"\nRMSE = {RMSE*100:.0f} cm"
    f"\nMAE = {MAE*100:.0f} cm"
    f"\nbias = {bias*100:.0f} cm\n"
    f"\nTerrestrial:"
    f"\nR² = {r2_odr_terrestrial:.2f}"
    f"\nRMSE = {RMSE_terrestrial*100:.0f} cm"
    f"\nMAE = {MAE_terrestrial*100:.0f} cm"
    f"\nbias = {bias_terrestrial*100:.0f} cm\n"
    f"\nSea ice:"
    f"\nR² = {r2_odr_seaice:.2f}"
    f"\nRMSE = {RMSE_seaice*100:.0f} cm"
    f"\nMAE = {MAE_seaice*100:.0f} cm"
    f"\nbias = {bias_seaice*100:.0f} cm" ,
    transform=ax_top_left.transAxes,
    va='bottom', ha='right',
    size=10,
    zorder=1e10
)


custom_legend_elements = []
for i, (target, dataset) in enumerate(zip(targets, sets)):
    custom_legend_elements.append(Line2D([0], [0], color=colors_list[i], lw=0, marker='o' if target == 'land' else '^', markersize=4, label=f'{dataset}'))
    
custom_legend_elements.append(Line2D([0], [0], color='none',  linestyle='none'))
custom_legend_elements.append(Line2D([0], [0], color='none',  linestyle='none'))
custom_legend_elements.append(Line2D([0], [0], color='none',  linestyle='none'))
custom_legend_elements.append(Line2D([0], [0], color='none',  linestyle='none'))
custom_legend_elements.append(Line2D([0], [0], color='none',  linestyle='none'))
custom_legend_elements.append(Line2D([0], [0], color='none',  linestyle='none'))

leg= ax_top_left.legend(handles=custom_legend_elements, loc='upper left', fontsize=8, frameon=False,
            bbox_to_anchor=(0, 0.945), ncol=2
            )
leg.set_zorder(1e10)


custom_legend_elements = [
    Line2D([0], [0], color='deepskyblue', lw=2, alpha=.4, label='ODR'),
    Line2D([0], [0], color='grey', lw=4, alpha=.2, label='$y=x \pm \: u_\mathrm{sampling}$'),
    # Line2D([0], [0], color='none',  linestyle='none'),
    Line2D([0], [0], lw=1.2, color='silver', markerfacecolor='grey', markeredgecolor='none', marker='o', markersize=6, label='Data points + uncertainties'),
    Line2D([0], [0], lw=1.2, color='silver', markerfacecolor='firebrick', markeredgecolor='none', marker='o', markersize=6, label='MP from internal layer'),
]
leg= ax_top_right.legend(handles=custom_legend_elements, loc='upper left', fontsize=10, frameon=False,
            bbox_to_anchor=(0, 0.945), ncol=1
            )
leg.set_zorder(1e10)

ax_bottom_1.bar(sets, R2s, color=colors_list, label='R²')
ax_bottom_2.bar(sets, np.multiply(RMSEs, 100), color=colors_list, label='RMSE')
ax_bottom_3.bar(sets, np.multiply(MAEs, 100), color=colors_list, label='MAE')

# %%
fig.savefig('./export/fig06.pdf', dpi=600)
